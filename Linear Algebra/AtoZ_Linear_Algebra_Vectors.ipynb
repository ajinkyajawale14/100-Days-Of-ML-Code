# %% [markdown]
# # Linear Algebra
#
#     1. matrix multiplication
#     2. vectors
#
#     Why ML algo uses Linear algebra?
#
#     it is easier to visualize the 2d 3d data but most of the time we encountered with multi dimentional data so, we use linear algebra
#
#     understanding data in multi dimentional way
#
#     Applications:
#
#     1. kernel in svm (support vector machine)
#     2. stochastic gradient descent (sgd) -> Neural Network uses the Linear Algebra

# %% [markdown]
#    # Vector
#    an entity with Magnitute & Direction
#
#    1. Unit Vector
#    Vector with magnetude 1
#    a^ = a / |a|
#
#    unit vector Vector in the direction of unit vector with magnetude 1
#
#    2. Row vector
#
#       vector in the form of n rows
#
#    3. Column vector
#
#       vector in the form of n column
#
#    * whenever we say as a vector its a column vector

# %% [markdown]
# # Representation of Vectors
#
# Addition of Vectors
#
# ![Screenshot%20%28130%29.png](attachment:Screenshot%20%28130%29.png)
#
# Multiplication of Vectors with scalar value
#
#     basic multiplication of Vector will be done
#
# Multiplication of the two Vectors
#
#     Dot Product
#
#     ![Screenshot%20%28131%29.png](attachment:Screenshot%20%28131%29.png)

# %% [markdown]
# # Vector Spaces
#     any operation vector,the vector will still present in same dataset
#
#     'v' & 'w'
#     c1 & c2 ->scalar
#
#     L(v,w)=(c1*v+ c2*w)    =>vector
