# %% [raw]
# # Matrices
#
#    1. For addition and substraction dimentions of the both matrices should be same
#    2. multiplication
#    dim (A) = a1 x a2      #cross product
#    dim (B) = b1 x b2      #cross product
#
#      A x B ->   a2 = b1
#      B X a ->   b2 = a1

# %% [markdown]
# ![Screenshot%20%28132%29.png](attachment:Screenshot%20%28132%29.png)

# %%
import numpy as np
x = np.matrix([[1,2,3,4],[5,6,7,8],[2,3,4,5],[6,7,8,9]])

# %%
x
# Out:
# matrix([[1, 2, 3, 4],
#         [5, 6, 7, 8],
#         [2, 3, 4, 5],
#         [6, 7, 8, 9]])

# %%
x.shape
# Out:
# (4, 4)

# %%
a=np.matrix([[1,4,5],[2,3,4],[5,6,7]])

# %%
a
# Out:
# matrix([[1, 4, 5],
#         [2, 3, 4],
#         [5, 6, 7]])

# %%
b=np.matrix([[2],[3],[4]])

# %%
b
# Out:
# matrix([[2],
#         [3],
#         [4]])

# %%
a.shape
# Out:
# (3, 3)

# %%
b.shape
# Out:
# (3, 1)

# %%
print(a*b)
# Out:
# [[34]
#  [29]
#  [56]]

# %% [markdown]
# # Transpose
#
#             T
#     | a  b |   =  | a   c |
#     | c  d |      | b   d |

# %% [markdown]
# # Linear Equations
#
#
# ![Screenshot%20%28133%29.png](attachment:Screenshot%20%28133%29.png)

# %% [markdown]
# # Linear Independance
# ![Screenshot%20%28134%29.png](attachment:Screenshot%20%28134%29.png)
#
#   yes very same concept from first Year

# %% [raw]
# Rank of a Matrix
#
# count of the number of linearly indepedent column
#
#     in above example, there are 2 linearly indepedent column
#                               & 1 linearly depedent column
#
#
# in machine learning we have to remove those dependent column

# %%
# so how to identify them or
# how to find rank of the matrix
from numpy import linalg as LA

x=np.matrix([[1,3,1],[2,2,1],[3,5,3]])
x
# Out:
# matrix([[1, 3, 1],
#         [2, 2, 1],
#         [3, 5, 3]])

# %%
x.shape
# Out:
# (3, 3)

# %%
#for finding rank
LA.matrix_rank(x)
# Out:
# 3

# %% [markdown]
# # Multi-Collinearity
#
#     Reduntancy of data
#     adds variance in the data
#
#     1. if column vector is linear combination of other so, this column adding no extra information to the matrix. this is extra column
#     2. in matrices if linear independent, column is reffered as vector
#     3. linear dependence in matrix is perfect Multicollinearity
#
#     rank < dimension (linear dependence) => multicollinearity present in the data
#
#     this means there is data reduntancy which causes variance

# %% [markdown]
# # Determinants
#
#     square matrix of numeric values
#
#     1. look for Determinant value not come to be as 0
#         reason - it will impact in solving the inverse of matrix
#
#         What is Determinant?
#         in 2d space, Area of 1 sq unit shrunk to linearly dependent columns
#         or
#         simply product of eigen values

# %% [markdown]
# # inverse of matrix
#
#     ( A * B )^-1 = B^-1  *  A^-1
#
#     (A * B * C * D)^-1 = D^-1 * C^-1  * B^-1  * A^-1

# %% [markdown]
# # 2D to N-D
#
# Consider ploting equations on plane
#
# 2D w1x1 + w2x2 + w0 = 0
# 3D w1x1 + w2x2 + w3x3 + w0 =0
#
# Hyperplane
#
# N-D  w1x1 + w2x2 + w3x3 + ... + wnxn = 0
#
#      w^T = [ w1 w2 w3 .... wn]
#
# ![Screenshot%20%28135%29.png](attachment:Screenshot%20%28135%29.png)
#
#
# so equation is if line passing through origin
#
#         w^T x = 0

# %% [markdown]
# all the p points on the same side as of w will be +ve
#
# all the p points on the other side as of w(of the plane) will be -ve
#
#      d= w^t p / | w |
#
# ![Screenshot%20%28136%29.png](attachment:Screenshot%20%28136%29.png)
